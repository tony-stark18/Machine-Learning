# %%
import numpy as np
import pandas as pd
from numpy import random

# %%
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
list(zip(outside,inside))
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
df = pd.DataFrame(random.randn(6,2),hier_index,['A','B'])

# %%
df
# Out:
#              A         B
# G1 1  0.482627 -1.124247
#    2  0.014801 -0.623540
#    3 -0.371238  0.469873
# G2 1  0.005267  0.276795
#    2  0.814037  0.076497
#    3 -1.819405  0.385643

# %%
df.loc['G1']
# Out:
#           A         B
# 1  0.482627 -1.124247
# 2  0.014801 -0.623540
# 3 -0.371238  0.469873

# %%
df.loc['G1'].loc[1]
# Out:
# A    0.482627
# B   -1.124247
# Name: 1, dtype: float64

# %%
df.index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Groups','Num']

# %%
df
# Out:
#                    A         B
# Groups Num
# G1     1    0.482627 -1.124247
#        2    0.014801 -0.623540
#        3   -0.371238  0.469873
# G2     1    0.005267  0.276795
#        2    0.814037  0.076497
#        3   -1.819405  0.385643

# %%
df.loc['G2']
# Out:
#             A         B
# Num
# 1    0.005267  0.276795
# 2    0.814037  0.076497
# 3   -1.819405  0.385643

# %%
df.loc['G2'].loc[2]
# Out:
# A    0.814037
# B    0.076497
# Name: 2, dtype: float64

# %%
df.loc['G2']['A']
# Out:
# Num
# 1    0.005267
# 2    0.814037
# 3   -1.819405
# Name: A, dtype: float64

# %%
df['B']
# Out:
# Groups  Num
# G1      1     -1.124247
#         2     -0.623540
#         3      0.469873
# G2      1      0.276795
#         2      0.076497
#         3      0.385643
# Name: B, dtype: float64

# %%
df.xs('G1')
# Out:
#             A         B
# Num
# 1    0.482627 -1.124247
# 2    0.014801 -0.623540
# 3   -0.371238  0.469873

# %%
df.xs(1,level='Num')
# Out:
#                A         B
# Groups
# G1      0.482627 -1.124247
# G2      0.005267  0.276795

# %%
df.loc['G2']
# Out:
#             A         B
# Num
# 1    0.005267  0.276795
# 2    0.814037  0.076497
# 3   -1.819405  0.385643
